# %%
# importing shapely subpackages
import shapely.geometry
import shapely.wkt

# %%
# Creating a polygon from Well Known Text
s_poly1 = shapely.wkt.loads("POLYGON ((0 0, 0 -2, 9 -2, 9 0, 0 0))")
s_poly1
# Out:
# <POLYGON ((0 0, 0 -2, 9 -2, 9 0, 0 0))>

# %%
# If you don't repeat the first and last coordiante to close the polygon, Shapely will throw an error.
s_poly2 = shapely.wkt.loads("POLYGON ((0 0, 0 -2, 9 -2, 9 0))")
s_poly2
# Out:
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 # If you don't repeat the first and last coordiante to close the polygon, Shapely will throw an error.
# ----> 2 s_poly2 = shapely.wkt.loads("POLYGON ((0 0, 0 -2, 9 -2, 9 0))")
#       3 s_poly2
#
# File c:\Data\LearnMLAI\Applied-Geospatial-Data-Science-with-Python\.venv\Lib\site-packages\shapely\wkt.py:22, in loads(data)
#       9 def loads(data):
#      10     """Load a geometry from a WKT string.
#      11
#      12     Parameters
#    (...)     20
#      21     """
# ---> 22     return shapely.from_wkt(data)
#
# File c:\Data\LearnMLAI\Applied-Geospatial-Data-Science-with-Python\.venv\Lib\site-packages\shapely\io.py:305, in from_wkt(geometry, on_invalid, **kwargs)
#     301     raise TypeError("on_invalid only accepts scalar values")
#     303 invalid_handler = np.uint8(DecodingErrorOptions.get_value(on_invalid))
# --> 305 return lib.from_wkt(geometry, invalid_handler, **kwargs)
#
# GEOSException: IllegalArgumentException: Points of LinearRing do not form a closed linestring

# %%
# Creating the same polygon from GeoJSON
from shapely.geometry import Polygon
geo = {'type': 'Polygon',
 'coordinates': [[[0, 0],
   [0, -2],
   [9, -2],
   [9, 0]]]}
Polygon([tuple(l) for l in geo['coordinates'][0]])
# Out:
# <POLYGON ((0 0, 0 -2, 9 -2, 9 0, 0 0))>

# %%
# Shapely Multi-Polygon
s_poly3 = shapely.wkt.loads("""
MULTIPOLYGON
(((50 40, 20 45, 45 30, 50 40)),
((25 35, 10 30, 10 18, 30 5, 45 20, 25 35), (32 20, 26 15, 20 25, 32 20)))
""")
s_poly3
# Out:
# <MULTIPOLYGON (((50 40, 20 45, 45 30, 50 40)), ((25 35, 10 30, 10 18, 30 5, ...>

# %%
# Produce a Shapely LineString geometry from a list of coordinates
coords = [(5, 0.5), (5, 3), (-2, 0), (8, 0)]
line = shapely.geometry.LineString(coords)
line
# Out:
# <LINESTRING (5 0.5, 5 3, -2 0, 8 0)>
